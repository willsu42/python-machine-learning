# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore
cred = credentials.Certificate("/Users/willsu/Downloads/project-98a90-firebase-adminsdk-v0bde-21f7677ee6.json")
firebase_admin.initialize_app(cred)

db = firestore.client()

# %%
doc = {
    'name': "abc",
    'email': "abc@gmail.com"
}

# 語法
# collection_ref = db.collection("集合路徑")

collection_ref = db.collection("pyradise_students")

# collection_ref提供一個add的方法，input必須是文件，型別是dictionary

collection_ref.add(doc)
# Out:
# (seconds: 1574068459
#  nanos: 292145000,
#  <google.cloud.firestore_v1.document.DocumentReference at 0x104f79c50>)

# %%
doc_ref = db.collection('p1').document('stockclose')

doc_ref.set({
'price': a,
})
# Out:
# update_time {
#   seconds: 1574080499
#   nanos: 174374000
# }

# %%
import pandas_datareader as pdr
startTime = '2019-1-01'

df_2330 = pdr.DataReader('2330.TW', 'yahoo', startTime)
for i in range(0,90): 
    a=df_2330.iloc[i,3]
    doc_ref = db.collection('price').document('stock2330')
    s=str(i)
    doc_ref.update({
    s:a,
    })
    print(s,a)
# Out:
# 0 219.5
# 1 215.5
# 2 208.0
# 3 213.0
# 4 211.0
# 5 215.5
# 6 216.0
# 7 220.5
# 8 218.5
# 9 221.0
# 10 217.5
# 11 220.5
# 12 218.5
# 13 221.0
# 14 223.0
# 15 220.5
# 16 222.5
# 17 226.0
# 18 229.0
# 19 222.5
# 20 221.0
# 21 228.0
# 22 230.0
# 23 229.0
# 24 227.0
# 25 227.0
# 26 230.0
# 27 229.0
# 28 234.5
# 29 236.5
# 30 236.5
# 31 238.0
# 32 239.5
# 33 239.0
# 34 235.5
# 35 233.0
# 36 234.0
# 37 234.0
# 38 230.0
# 39 230.5
# 40 235.5
# 41 237.0
# 42 234.5
# 43 239.0
# 44 241.0
# 45 240.5
# 46 242.0
# 47 245.5
# 48 248.5
# 49 241.5
# 50 244.0
# 51 241.5
# 52 242.0
# 53 245.5
# 54 245.5
# 55 246.0
# 56 246.5
# 57 253.0
# 58 254.0
# 59 254.0
# 60 252.0
# 61 252.0
# 62 255.5
# 63 257.0
# 64 261.5
# 65 264.5
# 66 264.5
# 67 266.0
# 68 268.0
# 69 269.0
# 70 267.5
# 71 260.0
# 72 259.5
# 73 259.0
# 74 259.0
# 75 265.0
# 76 259.0
# 77 262.5
# 78 260.0
# 79 256.5
# 80 256.0
# 81 250.5
# 82 248.5
# 83 249.0
# 84 247.0
# 85 241.5
# 86 238.0
# 87 234.0
# 88 238.0
# 89 230.0

# %%
df_2330
# Out:
#              High    Low   Open  Close    Volume   Adj Close
# Date
# 2019-01-02  226.5  219.0  226.5  219.5  32900482  210.842331
# 2019-01-03  218.0  214.0  214.0  215.5  34087620  207.000092
# 2019-01-04  211.5  206.5  211.5  208.0  65943521  199.795929
# 2019-01-07  214.0  211.0  212.0  213.0  35442176  204.598709
# 2019-01-08  212.5  210.0  212.0  211.0  22694481  202.677597
# 2019-01-09  216.5  211.0  212.0  215.5  46295446  207.000092
# 2019-01-10  216.5  214.5  216.0  216.0  20754593  207.480377
# 2019-01-11  220.5  218.0  219.0  220.5  28102288  211.802887
# 2019-01-14  220.0  217.0  218.5  218.5  17612296  209.881775
# 2019-01-15  221.0  215.5  216.5  221.0  38882923  212.283157
# 2019-01-16  220.0  217.5  218.5  217.5  28978282  208.921219
# 2019-01-17  221.0  218.0  218.0  220.5  21163986  211.802887
# 2019-01-18  220.0  217.5  219.0  218.5  49627569  209.881775
# 2019-01-21  223.0  220.0  220.0  221.0  29384866  212.283157
# ...

# %%
df_2330.index
# Out:
# DatetimeIndex(['2019-01-02', '2019-01-03', '2019-01-04', '2019-01-07',
#                '2019-01-08', '2019-01-09', '2019-01-10', '2019-01-11',
#                '2019-01-14', '2019-01-15',
#                ...
#                '2019-11-05', '2019-11-06', '2019-11-07', '2019-11-08',
#                '2019-11-11', '2019-11-12', '2019-11-13', '2019-11-14',
#                '2019-11-15', '2019-11-18'],
#               dtype='datetime64[ns]', name='Date', length=210, freq=None)

# %%
df_2330.index('Date')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-841c8198d7a9> in <module>
# ----> 1 df_2330.index('Date')
#
# TypeError: 'DatetimeIndex' object is not callable

# %%
i=1.0
type(i)
# Out:
# float

# %%
b=str(i)
type(b)
# Out:
# str

# %%
import pandas_datareader as pdr
startTime = '2018-11-01'

df_2330 = pdr.DataReader('2330.TW', 'yahoo', startTime,'2019-1-02')

# %%
df_2330
# Out:
#              High    Low   Open  Close    Volume   Adj Close
# Date
# 2018-11-01  237.0  233.0  236.0  235.5  41974797  226.211243
# 2018-11-02  236.5  233.5  236.5  236.5  30722361  227.171799
# 2018-11-05  235.5  232.0  233.0  235.0  25452065  225.730972
# 2018-11-06  235.5  232.5  234.0  234.5  30468176  225.250687
# 2018-11-07  236.0  232.5  233.0  234.0  34424652  224.770416
# 2018-11-08  237.5  236.0  237.5  236.5  24739146  227.171799
# 2018-11-09  234.5  231.0  234.5  231.0  23219081  221.888733
# 2018-11-12  234.5  230.0  230.0  231.5  23228445  222.369019
# 2018-11-13  228.0  224.5  224.5  227.5  36104127  218.526794
# 2018-11-14  231.0  228.5  230.0  228.5  20028279  219.487350
# 2018-11-15  232.0  228.5  229.5  231.0  22072228  221.888733
# 2018-11-16  229.0  225.0  229.0  226.0  46738909  217.085953
# 2018-11-19  225.0  221.0  225.0  222.0  48944754  213.243729
# 2018-11-20  220.5  218.0  219.0  218.0  41569756  209.401505
# ...
